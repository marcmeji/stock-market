# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
companies = pd.read_csv('companies.csv')
companies.head()
# Out:
#          Date   Last   Open    Max    Min    Vol  Var_%  Company
# 0  2019-10-22  92.05  91.60  92.70  91.40  52.67  -0.05  Acciona
# 1  2019-10-21  92.10  91.35  92.10  90.80  56.13   0.99  Acciona
# 2  2019-10-18  91.20  92.10  92.55  90.90  54.43  -0.98  Acciona
# 3  2019-10-17  92.10  92.10  92.35  91.25  70.36   0.11  Acciona
# 4  2019-10-16  92.00  91.20  92.70  90.75  73.84   0.33  Acciona

# %%
comp_names = list(companies['Company'].unique())

# %%
list_of_dfs = [companies.loc[companies['Company']==comp] for comp in comp_names]

# %%
for i in range(len(list_of_dfs)):
    comp_names[i] = list_of_dfs[i]

# %%
companies['Company'].unique()
# Out:
# array(['Acciona', 'Acerinox', 'ACS', 'AENA', 'Amadeus', 'ArcelorMittal',
#        'BancoSantander', 'BancSabadell', 'Bankia', 'Bankinter', 'BBVA',
#        'Caixabank', 'Cellnex', 'CIEAutomotive', 'Colonial', 'Enagas',
#        'ENCE', 'Endesa', 'Ferrovial', 'Grifols', 'Iberdrola', 'ICAG',
#        'Inditex', 'Indra', 'Mapfre', 'MasMovil', 'Mediaset', 'Melia',
#        'Merlin', 'Naturgy', 'RedElectrica', 'Repsol', 'SiemensGamesa',
#        'Telefonica', 'Viscofan'], dtype=object)

# %%
# separo empreses del dataframe comu en 35 dataframes

df_acciona = comp_names[0]
df_acerinox = comp_names[1]
df_acs = comp_names[2]
df_aena = comp_names[3]
df_amadeus = comp_names[4]
df_arcelor = comp_names[5]
df_santander = comp_names[6]
df_sabadell = comp_names[7]
df_bankia = comp_names[8]
df_bankinter = comp_names[9]
df_bbva = comp_names[10]
df_caixabank = comp_names[11]
df_cellnex = comp_names[12]
df_ciea = comp_names[13]
df_colonial = comp_names[14]
df_enagas = comp_names[15]
df_ence = comp_names[16]
df_endesa = comp_names[17]
df_ferrovial = comp_names[18]
df_grifols = comp_names[19]
df_iberdrola = comp_names[20]
df_icag = comp_names[21]
df_inditex = comp_names[22]
df_indra = comp_names[23]
df_mapfre = comp_names[24]
df_masmovil = comp_names[25]
df_mediaset = comp_names[26]
df_melia = comp_names[27]
df_merlin = comp_names[28]
df_naturgy = comp_names[29]
df_redelec = comp_names[30]
df_repsol = comp_names[31]
df_siemens = comp_names[32]
df_telefonica = comp_names[33]
df_viscofan = comp_names[34]

# %%
df_acciona.head()
# Out:
#          Date   Last   Open    Max    Min    Vol  Var_%  Company
# 0  2019-10-22  92.05  91.60  92.70  91.40  52.67  -0.05  Acciona
# 1  2019-10-21  92.10  91.35  92.10  90.80  56.13   0.99  Acciona
# 2  2019-10-18  91.20  92.10  92.55  90.90  54.43  -0.98  Acciona
# 3  2019-10-17  92.10  92.10  92.35  91.25  70.36   0.11  Acciona
# 4  2019-10-16  92.00  91.20  92.70  90.75  73.84   0.33  Acciona

# %%
df_acciona =

# %%
df_acciona_red = df_acciona[['Date', 'Last']]

# %%
plt.figure(figsize=(25,8))
sns.set(style="darkgrid")
sns.lineplot(x="Date", y="Last", data=df_acciona_red)

# %%
df_acciona_red.isna().sum()
# Out:
# Date    0
# Last    0
# dtype: int64

# %%
df_acciona_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2159 entries, 0 to 2158
# Data columns (total 2 columns):
# Date    2159 non-null object
# Last    2159 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 50.6+ KB

# %%
plt.figure(figsize=(25,8))
sns.set(style="darkgrid")
sns.lineplot(x="Date", y="Last", data=companies.loc[companies['Company']=='Acciona'])
