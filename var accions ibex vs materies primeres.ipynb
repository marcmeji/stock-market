# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
companies = pd.read_csv('data/ibex35 companies/Clean dfs/companies_clean.csv')

# %%
companies.shape
# Out:
# (70806, 8)

# %%
companies.head()
# Out:
#          Date   Last   Open    Max    Min    Vol  Var_%  Company
# 0  2019-10-22  92.05  91.60  92.70  91.40  52.67  -0.05  Acciona
# 1  2019-10-21  92.10  91.35  92.10  90.80  56.13   0.99  Acciona
# 2  2019-10-18  91.20  92.10  92.55  90.90  54.43  -0.98  Acciona
# 3  2019-10-17  92.10  92.10  92.35  91.25  70.36   0.11  Acciona
# 4  2019-10-16  92.00  91.20  92.70  90.75  73.84   0.33  Acciona

# %%
import glob
import re

files = glob.glob('data/raw materials/Clean dfs/*.csv')

index_names = []

for file in files:
    name = re.findall('\\\(.+).csv', file)
    name_string = ''.join(name)
    index_names.append(name_string)


for i in range(len(index_names)):
    index_names[i] = pd.read_csv('data/raw materials/Clean dfs/'+index_names[i]+'.csv', index_col=None, header=0)

# %%
files
# Out:
# ['data/raw materials/Clean dfs\\copper.csv',
#  'data/raw materials/Clean dfs\\cotton.csv',
#  'data/raw materials/Clean dfs\\gasnat.csv',
#  'data/raw materials/Clean dfs\\gold.csv',
#  'data/raw materials/Clean dfs\\petrol.csv',
#  'data/raw materials/Clean dfs\\rice.csv',
#  'data/raw materials/Clean dfs\\soy.csv',
#  'data/raw materials/Clean dfs\\wheat.csv']

# %%
copper = index_names[0]
cotton = index_names[1]
gasnat = index_names[2]
gold = index_names[3]
petrol = index_names[4]
rice = index_names[5]
soy = index_names[6]
wheat = index_names[7]

# %%
#copper

var_averages = []
var_averages3 = []

for row in range(len(copper['Var_%'])):
            
    avg = np.mean(copper['Var_%'][row+1:row+6])
    var_averages.append(round(avg,3))
    
    avg3 = np.mean(copper['Var_%'][row+1:row+4])
    var_averages3.append(round(avg3,3))
    
    
copper['copper_last_5_avg'] = var_averages
copper['copper_last_3_avg'] = var_averages3
copper['copper_last_1'] = copper['Var_%'].shift(-1)
copper.head()
# Out:
#          Date   Last   Open    Max    Min  Vol_K  Var_% Materials  \
# 0  2019-10-23  2.671  2.635  2.675  2.615  75.68   1.44    copper
# 1  2019-10-22  2.633  2.645  2.651  2.630  46.14  -0.53    copper
# 2  2019-10-21  2.647  2.639  2.660  2.631  54.49   0.42    copper
# 3  2019-10-18  2.636  2.600  2.646  2.585  71.81   1.46    copper
# 4  2019-10-17  2.598  2.587  2.618  2.577  53.90   0.31    copper
#
#    copper_last_5_avg  copper_last_3_avg  copper_last_1
# 0              0.148              0.450          -0.53
# 1              0.102              0.730           0.42
# 2              0.064              0.283           1.46
# 3             -0.120             -0.457           0.31
# 4              0.176             -0.483          -0.92

# %%
# cotton

var_averages = []
var_averages3 = []

for row in range(len(cotton['Var_%'])):
    avg = np.mean(cotton['Var_%'][row+1:row+6])
    var_averages.append(round(avg,3))
    
    avg3 = np.mean(cotton['Var_%'][row+1:row+4])
    var_averages3.append(round(avg3,3))
    
    
cotton['cotton_last_5_avg'] = var_averages
cotton['cotton_last_3_avg'] = var_averages3
cotton['cotton_last_1'] = cotton['Var_%'].shift(-1)
cotton.head()
# Out:
#          Date   Last   Open    Max    Min  Vol_K  Var_% Materials  \
# 0  2019-10-23  64.88  64.61  65.18  64.41    NaN   0.32    cotton
# 1  2019-10-22  64.67  64.39  65.19  63.97    NaN   0.34    cotton
# 2  2019-10-21  64.45  65.21  65.45  64.45    NaN  -1.12    cotton
# 3  2019-10-18  65.18  65.14  65.39  65.01    NaN   0.14    cotton
# 4  2019-10-17  65.09  64.53  65.14  64.20    NaN   0.84    cotton
#
#    cotton_last_5_avg  cotton_last_3_avg  cotton_last_1
# 0              0.394             -0.213           0.34
# 1              0.722             -0.047          -1.12
# 2              0.384              0.917           0.14
# 3              1.152              1.530           0.84
# 4              0.814              0.313           1.77

# %%
# gasnat
var_averages = []
var_averages3 = []

for row in range(len(gasnat['Var_%'])):
    avg = np.mean(gasnat['Var_%'][row+1:row+6])
    var_averages.append(round(avg,3))
    
    avg3 = np.mean(gasnat['Var_%'][row+1:row+4])
    var_averages3.append(round(avg3,3))
    
gasnat['gasnat_last_5_avg'] = var_averages
gasnat['gasnat_last_3_avg'] = var_averages3
gasnat['gasnat_last_1'] = gasnat['Var_%'].shift(-1)
gasnat.head()
# Out:
#          Date   Last   Open    Max    Min   Vol_K  Var_%     Materials  \
# 0  2019-10-23  2.282  2.274  2.305  2.251  130.45   0.44  gasnat_price
# 1  2019-10-22  2.272  2.236  2.311  2.231  234.96   1.52  gasnat_price
# 2  2019-10-21  2.238  2.320  2.322  2.213  215.76  -3.53  gasnat_price
# 3  2019-10-18  2.320  2.319  2.360  2.289  150.02   0.09  gasnat_price
# 4  2019-10-17  2.318  2.292  2.365  2.284  159.78   0.65  gasnat_price
#
#    gasnat_last_5_avg  gasnat_last_3_avg  gasnat_last_1
# 0             -0.562             -0.640           1.52
# 1             -0.348             -0.930          -3.53
# 2              0.954             -0.267           0.09
# 3              0.900              0.567           0.65
# 4              0.626              1.343          -1.54

# %%
# gold

var_averages = []
var_averages3 = []

for row in range(len(gold['Var_%'])):
    avg = np.mean(gold['Var_%'][row+1:row+6])
    var_averages.append(round(avg,3))
    
    avg3 = np.mean(gold['Var_%'][row+1:row+4])
    var_averages3.append(round(avg3,3))
    
gold['gold_last_5_avg'] = var_averages
gold['gold_last_3_avg'] = var_averages3
gold['gold_last_1'] = gold['Var_%'].shift(-1)
gold.head()
# Out:
#          Date    Last    Open     Max     Min   Vol_K  Var_% Materials  \
# 0  2019-10-23  1495.7  1491.1  1499.4  1490.7  237.36   0.55      gold
# 1  2019-10-22  1487.5  1487.5  1492.1  1484.0  208.97  -0.04      gold
# 2  2019-10-21  1488.1  1495.6  1498.7  1484.8  284.29  -0.40      gold
# 3  2019-10-18  1494.1  1495.6  1497.9  1488.3  232.55  -0.28      gold
# 4  2019-10-17  1498.3  1494.2  1501.1  1487.0  305.67   0.29      gold
#
#    gold_last_5_avg  gold_last_3_avg  gold_last_1
# 0            0.056           -0.240        -0.04
# 1           -0.124           -0.130        -0.40
# 2            0.076            0.240        -0.28
# 3           -0.030            0.020         0.29
# 4           -0.246            0.123         0.71

# %%
# petrol

var_averages = []
var_averages3 = []

for row in range(len(petrol['Var_%'])):
    avg = np.mean(petrol['Var_%'][row+1:row+6])
    var_averages.append(round(avg,3))
    
    avg3 = np.mean(petrol['Var_%'][row+1:row+4])
    var_averages3.append(round(avg3,3))
    
petrol['petrol_last_5_avg'] = var_averages
petrol['petrol_last_3_avg'] = var_averages3
petrol['petrol_last_1'] = petrol['Var_%'].shift(-1)
petrol.head()
# Out:
#          Date   Last   Open    Max    Min   Vol_K  Var_%     Materials  \
# 0  2019-10-23  61.17  59.48  61.30  58.85  313.23   2.46  petrol_brent
# 1  2019-10-22  59.70  59.05  60.26  58.75  260.60   1.26  petrol_brent
# 2  2019-10-21  58.96  59.23  59.55  58.26  212.57  -0.77  petrol_brent
# 3  2019-10-18  59.42  59.78  60.29  59.01  228.14  -0.82  petrol_brent
# 4  2019-10-17  59.91  58.99  60.04  58.69  269.84   0.82  petrol_brent
#
#    petrol_last_5_avg  petrol_last_3_avg  petrol_last_1
# 0              0.330             -0.110           1.26
# 1             -0.128             -0.257          -0.77
# 2             -0.358              0.387          -0.82
# 3              0.284              0.317           0.82
# 4              0.388             -0.597           1.16

# %%
# rice

var_averages = []
var_averages3 = []

for row in range(len(rice['Var_%'])):
    avg = np.mean(rice['Var_%'][row+1:row+6])
    var_averages.append(round(avg,3))
    
    avg3 = np.mean(rice['Var_%'][row+1:row+4])
    var_averages3.append(round(avg3,3))
    
rice['rice_last_5_avg'] = var_averages
rice['rice_last_3_avg'] = var_averages3
rice['rice_last_1'] = rice['Var_%'].shift(-1)
rice.head()
# Out:
#          Date    Last    Open    Max     Min  Vol_K  Var_% Materials  \
# 0  2019-10-23  11.670  11.700  11.70  11.655   0.26  -0.26      rice
# 1  2019-10-22  11.700  11.800  11.90  11.690   0.55  -0.81      rice
# 2  2019-10-21  11.795  11.910  11.91  11.755   1.00  -0.97      rice
# 3  2019-10-18  11.910  11.975  11.99  11.890   0.48  -0.67      rice
# 4  2019-10-17  11.990  12.000  12.04  11.905   0.48   0.08      rice
#
#    rice_last_5_avg  rice_last_3_avg  rice_last_1
# 0           -0.314           -0.817        -0.81
# 1           -0.328           -0.520        -0.97
# 2           -0.250            0.070        -0.67
# 3           -0.082            0.000         0.08
# 4           -0.040           -0.220         0.80

# %%
# soy

var_averages = []
var_averages3 = []

for row in range(len(soy['Var_%'])):
    avg = np.mean(soy['Var_%'][row+1:row+6])
    var_averages.append(round(avg,3))
    
    avg3 = np.mean(soy['Var_%'][row+1:row+4])
    var_averages3.append(round(avg3,3))
    
soy['soy_last_5_avg'] = var_averages
soy['soy_last_3_avg'] = var_averages3
soy['soy_last_1'] = soy['Var_%'].shift(-1)
soy.head()
# Out:
#          Date    Last    Open     Max     Min  Vol_K  Var_% Materials  \
# 0  2019-10-23  934.75  933.88  938.62  927.88    NaN   0.08       soy
# 1  2019-10-22  934.00  932.88  945.12  931.12    NaN   0.05       soy
# 2  2019-10-21  933.50  931.62  939.88  930.38    NaN   0.05       soy
# 3  2019-10-20  933.00  933.00  933.00  933.00    NaN  -0.09       soy
# 4  2019-10-18  933.88  930.88  938.62  930.75    NaN   0.31       soy
#
#    soy_last_5_avg  soy_last_3_avg  soy_last_1
# 0           0.118           0.003        0.05
# 1           0.006           0.090        0.05
# 2          -0.142           0.163       -0.09
# 3          -0.010           0.023        0.31
# 4           0.186          -0.310        0.27

# %%
# wheat

var_averages = []
var_averages3 = []

for row in range(len(wheat['Var_%'])):
    avg = np.mean(wheat['Var_%'][row+1:row+6])
    var_averages.append(round(avg,3))
    
    avg3 = np.mean(wheat['Var_%'][row+1:row+4])
    var_averages3.append(round(avg3,3))
    
wheat['wheat_last_5_avg'] = var_averages
wheat['wheat_last_3_avg'] = var_averages3
wheat['wheat_last_1'] = wheat['Var_%'].shift(-1)
wheat.head()
# Out:
#          Date    Last    Open     Max     Min  Vol_K  Var_% Materials  \
# 0  2019-10-23  521.50  518.75  523.88  516.12    NaN   0.77     wheat
# 1  2019-10-22  517.50  523.62  532.12  517.50    NaN  -1.29     wheat
# 2  2019-10-21  524.25  530.38  534.88  522.88    NaN  -1.22     wheat
# 3  2019-10-18  530.75  525.62  532.38  521.12    NaN   1.10     wheat
# 4  2019-10-17  525.00  513.75  526.88  513.12    NaN   2.09     wheat
#
#    wheat_last_5_avg  wheat_last_3_avg  wheat_last_1
# 0             0.412            -0.470         -1.29
# 1             0.524             0.657         -1.22
# 2             0.896             1.523          1.10
# 3             0.602             0.913          2.09
# 4             0.932             0.430          1.38

# %% [markdown]
# ## Appending raw materials to companies dataframe

# %%
companies_reduced = companies[['Date', 'Company', 'Var_%']]

cac40_reduced = cac40[['Date', 'cac40_last_5_avg', 'cac40_last_3_avg', 'cac40_last_1']]
merged_dfs = companies_reduced.merge(cac40_reduced, on='Date')

chinaa50_reduced = chinaa50[['Date', 'chinaa50_last_5_avg', 'chinaa50_last_3_avg', 'chinaa50_last_1']]
merged_dfs = merged_dfs.merge(chinaa50_reduced, on='Date')

dax_reduced = dax[['Date', 'dax_last_5_avg', 'dax_last_3_avg', 'dax_last_1']]
merged_dfs = merged_dfs.merge(dax_reduced, on='Date')

dowjones_reduced = dowjones[['Date', 'dowjones_last_5_avg', 'dowjones_last_3_avg', 'dowjones_last_1']]
merged_dfs = merged_dfs.merge(dowjones_reduced, on='Date')

eurostoxx_reduced = eurostoxx[['Date', 'eurostoxx_last_5_avg','eurostoxx_last_3_avg', 'eurostoxx_last_1']]
merged_dfs = merged_dfs.merge(eurostoxx_reduced, on='Date')

ibex_reduced = ibex[['Date', 'ibex_last_5_avg', 'ibex_last_3_avg', 'ibex_last_1']]
merged_dfs = merged_dfs.merge(ibex_reduced, on='Date')

nasdaq_reduced = nasdaq[['Date', 'nasdaq_last_5_avg', 'nasdaq_last_3_avg', 'nasdaq_last_1']]
merged_dfs = merged_dfs.merge(nasdaq_reduced, on='Date')

nasdaq_reduced = nasdaq[['Date', 'nasdaq_last_5_avg', 'nasdaq_last_3_avg', 'nasdaq_last_1']]
merged_dfs = merged_dfs.merge(nasdaq_reduced, on='Date')


merged_dfs.head()
# Out:
#          Date   Company  Var_%  cac40_last_5_avg  cac40_last_3_avg  \
# 0  2019-10-22   Acciona  -0.05             0.018            -0.287
# 1  2019-10-22  Acerinox   0.00             0.018            -0.287
# 2  2019-10-22       ACS   0.25             0.018            -0.287
# 3  2019-10-22      AENA  -0.18             0.018            -0.287
# 4  2019-10-22   Amadeus  -1.18             0.018            -0.287
#
#    cac40_last_1  chinaa50_last_5_avg  chinaa50_last_3_avg  chinaa50_last_1  \
# 0          0.21               -0.188               -0.227             0.58
# 1          0.21               -0.188               -0.227             0.58
# 2          0.21               -0.188               -0.227             0.58
# 3          0.21               -0.188               -0.227             0.58
# 4          0.21               -0.188               -0.227             0.58
#
#    dax_last_5_avg      ...        dowjones_last_1  eurostoxx_last_5_avg  \
# ...

# %%
correlation = merged_dfs.corr()

plt.figure(figsize=(20,12))
sns.heatmap(correlation, annot=True)
plt.show()

# %% [markdown]
# ## Separating dataframes per IBEX35 company

# %%
acciona = merged_dfs.loc[merged_dfs['Company']=='Acciona'].reset_index(drop=True)

# %%
acciona.head()
# Out:
#          Date  Company  Var_%  cac40_last_5_avg  cac40_last_3_avg  \
# 0  2019-10-22  Acciona  -0.05             0.018            -0.287
# 1  2019-10-21  Acciona   0.99            -0.104            -0.387
# 2  2019-10-18  Acciona  -0.98             0.372             0.177
# 3  2019-10-17  Acciona   0.11             0.710             0.183
# 4  2019-10-16  Acciona   0.33             0.884             0.790
#
#    cac40_last_1  chinaa50_last_5_avg  chinaa50_last_3_avg  chinaa50_last_1  \
# 0          0.21               -0.188               -0.227             0.58
# 1         -0.65               -0.114               -0.537            -1.53
# 2         -0.42                0.480                0.003             0.27
# 3         -0.09                0.492                0.230            -0.35
# 4          1.04                0.568                0.827             0.09
#
#    dax_last_5_avg      ...        dowjones_last_1  eurostoxx_last_5_avg  \
# ...

# %%
correlation = acciona.corr()

plt.figure(figsize=(20,12))
sns.heatmap(correlation, annot=True)
plt.show()

# %%
merged_dfs.describe().T
# Out:
#                         count      mean       std     min    25%    50%  \
# Var_%                 60544.0  0.027623  1.411828  -3.750 -0.840  0.000
# cac40_last_5_avg      60544.0  0.034411  0.486232  -2.524 -0.210  0.058
# cac40_last_3_avg      60544.0  0.035659  0.658739  -3.533 -0.283  0.060
# cac40_last_1          60544.0  0.030278  1.135695  -8.040 -0.520  0.040
# chinaa50_last_5_avg   60544.0  0.039011  0.652812  -4.202 -0.314  0.042
# chinaa50_last_3_avg   60544.0  0.043803  0.849380  -6.363 -0.410  0.033
# chinaa50_last_1       60544.0  0.041766  1.485885  -9.280 -0.620  0.000
# dax_last_5_avg        60544.0  0.046002  0.509713  -2.470 -0.242  0.074
# dax_last_3_avg        60544.0  0.046458  0.676731  -3.330 -0.317  0.073
# dax_last_1            60544.0  0.044101  1.150948  -6.820 -0.520  0.080
# dowjones_last_5_avg   60544.0  0.047888  0.358560  -2.194 -0.128  0.070
# dowjones_last_3_avg   60544.0  0.050535  0.471573  -2.917 -0.177  0.070
# ...

# %%
# Try without null values

merged_nonulls = merged_dfs.dropna()

correlation = merged_nonulls.corr()

plt.figure(figsize=(20,12))
sns.heatmap(correlation, annot=True)
plt.show()

# %%
sns.boxplot(merged_nonulls['Var_%']).set_title('Boxplot of Variation percentage (Stock)')
plt.show()

# %%
sns.distplot(merged_nonulls['Var_%']).set_title('Distribution of Variation percentage (Stock)')
plt.show()
